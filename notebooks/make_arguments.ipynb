# %%
from compo_predictive_learning.utils import jobmaker

common_ranges_cnn = {
    "compute_metrics": [True],
    "compute_clustering": [False],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "model": ["cnnae"],
    "model.activation": ["relu"],
    "model.noise":[0.05],
    "train_loop.pretrain_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[8,32,512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
    "make_plots": [False],
}

common_ranges_auto = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "model": ["rnnae"],
    "model.type": ["auto"],
    "rnn.noise":[0.05],
    "train_loop.pretrain_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    'rnn.hidden_dim':[32,256,512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

common_ranges_pred = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    "train_loop.pretrain_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

jobmaker.write_all_commands_to_file("../hyper_param_search.sh", 
                                      param_dicts=[common_ranges_cnn,common_ranges_auto,common_ranges_pred],
                                      command="python3 -u scripts/train_rnn.py",parallel=2,gpus=[1,2])
# Out:
# Generated 216 combinations.
# Generated 216 combinations.
# Generated 72 combinations.
# Warning: ../bashtout.sh already exists. Deleting it.
# [{'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 8,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128,
#   'make_plots': False},
#  {'compute_metrics': True,
#   'compute_clustering': False,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'model': 'cnnae',
#   'model.activation': 'relu',
#   'model.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
# ...
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128}]

# %%
from compo_predictive_learning.utils import jobmaker
common_ranges_auto = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "dataset": ["sketch"],

    "model": ["rnnae"],
    "model.type": ["auto"],
    "rnn.noise":[0.05],
    "train_loop.pretrain_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    'rnn.hidden_dim':[32,256,512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

common_ranges_mem = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "dataset": ["sketch"],
    "model": ["rnnae"],
    "model.type": ["mem"],
    "rnn.noise":[0.05],
    "train_loop.pretrain_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    'rnn.hidden_dim':[32,256,512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

common_ranges_pred = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "dataset": ["sketch"],
    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    "train_loop.pretrain_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

jobmaker.write_all_commands_to_file("../auto_mem_pred.sh", 
                                      param_dicts=[common_ranges_mem],
                                      command="python3 -u scripts/train_rnn.py",parallel=2,gpus=[0,1])
# Out:
# Generated 216 combinations.
# Warning: ../auto_mem_pred.sh already exists. Deleting it.
# [{'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
# ...
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128}]

# %%
from compo_predictive_learning.utils import jobmaker
common_ranges_auto = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "dataset": ["sketch"],

    "model": ["rnnae"],
    "model.type": ["auto"],
    "rnn.noise":[0.05],
    "train_loop.pretrain_decay":[1],
    "train_loop.pretrain_act_decay":[0],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    'rnn.hidden_dim':[32,256,512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

common_ranges_mem = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "dataset": ["sketch"],
    "model": ["rnnae"],
    "model.type": ["mem"],
    "rnn.noise":[0.05],
    "train_loop.pretrain_decay":[0.01],
    "train_loop.pretrain_act_decay":[0.01],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    'rnn.hidden_dim':[32,256,512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

common_ranges_pred = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "seed": [0,1],
    "dataset": ["sketch"],
    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    "train_loop.pretrain_decay":[0.001],
    "train_loop.pretrain_act_decay":[0.01],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "dataset.sequence_length": [6],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "train_loop.batch_size": [128],
}

jobmaker.write_all_commands_to_file("../auto_mem_pred.sh", 
                                      param_dicts=[common_ranges_auto,common_ranges_mem,common_ranges_pred],
                                      command="python3 -u scripts/train_rnn.py",parallel=2,gpus=[0,1])
# Out:
# Generated 216 combinations.
# Warning: ../auto_mem_pred.sh already exists. Deleting it.
# [{'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 0,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
# ...
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 32,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 256,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'seed': 1,
#   'dataset': 'sketch',
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'rnn.hidden_dim': 512,
#   'dataset.sequence_length': 6,
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'train_loop.batch_size': 128}]

# %%
from comp_predictive_learning.utils import jobmaker

common_ranges_un = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [20000],
    "train_loop.eval_every": [1000],
    "train_loop.compute_metrics_every": [1000],
    "dataset.next_shape_offset": [[0,1,2]],
    # "dataset.next_floor_offset": [[0,1,2]],
    "dataset.next_wall_offset": [[0,1,2]],
    "dataset.next_object_offset": [[0,1,2]],

    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[32,32,32]],
    'decoder.hidden_dims':[[32,32,32]],
    "train_loop.pretrain_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "train_loop.batch_size": [128],
    "seed": [0,1],
}
import copy
common_ranges_deux = copy.deepcopy(common_ranges_un)

common_ranges_deux["encoder.hidden_dims"] = [[16,16,16]]
common_ranges_deux["decoder.hidden_dims"] = [[16,16,16]]


jobmaker.write_all_commands_to_file("../auto_mem_pred.sh", 
                                      param_dicts=[common_ranges_deux],
                                      command="python3 -u scripts/train_rnn.py",parallel=1,gpus=[0])
# Out:
# Generated 72 combinations.
# Warning: ../auto_mem_pred.sh already exists. Deleting it.
# [{'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1}]

# %%
from comp_predictive_learning.utils import jobmaker

common_ranges_un = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [20000],
    "train_loop.eval_every": [1000],
    "train_loop.compute_metrics_every": [1000],
    "dataset.next_shape_offset": [[0,1,2]],
    # "dataset.next_floor_offset": [[0,1,2]],
    "dataset.next_wall_offset": [[0,1,2]],
    "dataset.next_object_offset": [[0,1,2]],

    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[32,32,32]],
    'decoder.hidden_dims':[[32,32,32]],
    "train_loop.pretrain_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "train_loop.batch_size": [128],
    "seed": [0,1],
}
import copy
common_ranges_deux = copy.deepcopy(common_ranges_un)

common_ranges_deux["encoder.hidden_dims"] = [[16,16,16]]
common_ranges_deux["decoder.hidden_dims"] = [[16,16,16]]


jobmaker.write_all_commands_to_file("../auto_mem_pred.sh", 
                                      param_dicts=[common_ranges_deux],
                                      command="python3 -u scripts/train_rnn.py",parallel=1,gpus=[0])

# %%
from comp_predictive_learning.utils import jobmaker

common_ranges_un = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [5000],
    "train_loop.eval_every": [256],
    "train_loop.compute_metrics_every": [256],
    "dataset":["sketch"],
    "dataset.colors": [["white","red","green","blue"]],
    "dataset.next_primitive_offset": [[0,1,2,3,4,5]],
    "dataset.next_color_offset":[[0,1,2]],
    "dataset.next_position_offset": [[0,1,2]],
    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    "rnn.activation":["tanh"],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    "train_loop.pretrain_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "train_loop.batch_size": [128],
    "seed": [0,1],
}


jobmaker.write_all_commands_to_file("../auto_mem_pred.sh", 
                                      param_dicts=[common_ranges_un],
                                      command="python3 -u scripts/train_rnn.py",parallel=1,gpus=[0])
# Out:
# Generated 72 combinations.
# Warning: ../auto_mem_pred.sh already exists. Deleting it.
# [{'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 5000,
#   'train_loop.eval_every': 256,
#   'train_loop.compute_metrics_every': 256,
#   'dataset': 'sketch',
#   'dataset.colors': ['white', 'red', 'green', 'blue'],
#   'dataset.next_primitive_offset': [0, 1, 2, 3, 4, 5],
#   'dataset.next_color_offset': [0, 1, 2],
#   'dataset.next_position_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'rnn.activation': 'tanh',
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1}]

# %%
from compo_predictive_learning.utils import jobmaker

common_ranges_un = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [15000],
    "train_loop.eval_every": [1000],
    "train_loop.compute_metrics_every": [1000],
    "train_loop.make_plots_every": [1000],
    "dataset": ["dddshapes"],
    "dataset.next_shape_offset": [[0,1,2]],
    "dataset.next_wall_offset": [[0,1,2]],
    "dataset.next_object_offset": [[0,1,2]],

    "model": ["rnnae"],
    "model.type": ["pred"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[16,16,16]],
    'decoder.hidden_dims':[[16,16,16]],
    "train_loop.pretrain_decay":[0.0001,0.001,0.01],
    "train_loop.pretrain_act_decay":[0.0001,0.001,0.01],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "train_loop.batch_size": [128],
    "seed": [0,1],
}

jobmaker.write_all_commands_to_file("../auto_mem_pred.sh", 
                                      param_dicts=[common_ranges_un],
                                      command="python3 -u scripts/train_rnn.py",parallel=2,gpus=[0,1])
# Out:
# Generated 18 combinations.
# Warning: ../auto_mem_pred.sh already exists. Deleting it.
# [{'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 15000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'train_loop.make_plots_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1}]

# %%
from compo_predictive_learning.utils import jobmaker

common_ranges_un = {
    "compute_metrics": [True],
    "compute_clustering": [True],
    "train_loop.num_steps": [20000],
    "train_loop.eval_every": [1000],
    "train_loop.compute_metrics_every": [1000],
    "dataset": ["dddshapes"],
    "dataset.next_shape_offset": [[0,1,2]],
    # "dataset.next_floor_offset": [[0,1,2]],
    "dataset.next_wall_offset": [[0,1,2]],
    "dataset.next_object_offset": [[0,1,2]],

    "model": ["rnnae"],
    "model.type": ["pred","auto","mem"],
    "rnn.noise":[0.05],
    'encoder.hidden_dims':[[32,32,32]],
    'decoder.hidden_dims':[[32,32,32]],
    "train_loop.pretrain_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_act_decay":[0.0001,0.001,0.01,0.1,1,10],
    "train_loop.pretrain_weight_l1":[0],
    "train_loop.pretrain_act_l1":[0],
    'encoder.output_dim':[512],
    'rnn.hidden_dim':[512],
    "train_loop.batch_size": [128],
    "seed": [0,1],
}
import copy
common_ranges_deux = copy.deepcopy(common_ranges_un)

common_ranges_deux["encoder.hidden_dims"] = [[16,16,16]]
common_ranges_deux["decoder.hidden_dims"] = [[16,16,16]]
   

qsub_headers = jobmaker.make_qsub_headers(
    walltime="01:30:00",
    ncpu=8,
    ngpu=1,
    mem="32",
)

extra = [
    "module load miniforge/3",     # if your cluster uses modules
    "module load CUDA/12.1.1",
    "eval \"$(~/miniforge3/bin/conda shell.bash hook)\" ",
    "conda activate pre",
    "cd comp_predictive_learning",  # cd to your repo
]

jobmaker.write_combinations_for_qsub_stdin_one_per_combo(
    qsub_submit_file_path="submit_jobs.sh",
    qsub_headers=qsub_headers,
    param_dicts=[common_ranges_deux], 
    command="python3 -u scripts/train_rnn.py",
    combination_style="hydra",
    extra_body_lines=extra,
    pass_env=True,
    throttle_sleep_seconds=600,
)
# Out:
# Generated 216 combinations.
# [{'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.0001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.001,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.01,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 0.1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'pred',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
# ...
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 1,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.0001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.001,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.01,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 0.1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 1,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 0},
#  {'compute_metrics': True,
#   'compute_clustering': True,
#   'train_loop.num_steps': 20000,
#   'train_loop.eval_every': 1000,
#   'train_loop.compute_metrics_every': 1000,
#   'dataset': 'dddshapes',
#   'dataset.next_shape_offset': [0, 1, 2],
#   'dataset.next_wall_offset': [0, 1, 2],
#   'dataset.next_object_offset': [0, 1, 2],
#   'model': 'rnnae',
#   'model.type': 'mem',
#   'rnn.noise': 0.05,
#   'encoder.hidden_dims': [16, 16, 16],
#   'decoder.hidden_dims': [16, 16, 16],
#   'train_loop.pretrain_decay': 10,
#   'train_loop.pretrain_act_decay': 10,
#   'train_loop.pretrain_weight_l1': 0,
#   'train_loop.pretrain_act_l1': 0,
#   'encoder.output_dim': 512,
#   'rnn.hidden_dim': 512,
#   'train_loop.batch_size': 128,
#   'seed': 1}]
